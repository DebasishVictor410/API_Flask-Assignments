# %% [markdown]
# ### Q1. What is Flask Framework? What are the advantages of Flask Framework?

# %%
#### Flask is a framework
#### Basically its a micro framework
#### It’s a Python module
#### It let us develop web applications easily
#### It’s has a small and easy-to-extend
#### it’s a microframework whicjh doesnot includes many haevy features
#### it has some very good feature like url routing, template engine
#### it is a collection of libraries and modules that enable web application
#### we can develop it without worrying about low-level details 
#### its not necessary to learn about protocol,how to manage thread
#### Web server gateway interface (WSGI) is an inteface between web applications
#### and web servers. It is used as a standard for python web application 
#### it’s very explicit which increases readability

#### advantages..
#### its scalable as we can use it to create a tech level project
#### its size is small
#### we can create our app as well as web application with that smoothly
#### its flexiable and simple as it can easily moved around and rearranged
#### it creates such structure that won't collapse
#### its lightweight as well as negotiable
#### easy to understand
#### it helps developers not only by saving time but also with less effort
#### it also supports modular programming
#### it has a well structured documentation and healty number of examples
#### its documentation is more than well mannered

# %% [markdown]
# ### Q2. Create a simple Flask application to display ‘Hello World!!’. Attach the screenshot of the output in Jupyter Notebook.

# %%
from flask import Flask,redirect,url_for

# %%
app=Flask(__name__)

# %%
@app.route("/hello")
def display_method():
    return "<h3>Hello World!!!</h3>"

if __name__=='__main__':
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.3:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![flask_hello-2.png](attachment:flask_hello-2.png)

# %% [markdown]
# ### Q3. What is App routing in Flask? Why do we use app routes?

# %%
#### App routing is a technique which is used to map the specific URL 
#### it does it with the help of defined function 
#### we write each function to perform some task
#### Flask framework uses the routing technique 
#### for remembering users application URLs. 
#### It is helpful to access the desired page directly 
#### without navigating from the home page.

#### use
#### The route() decorator in Flask is used to bind an URL to a function
#### consider hello world example
#### here we are binding that display function with browser url
#### here there are two hetrogenous system as one understands only python
#### and we understands HTML so here routing is required for bindling those two
#### so that they can communicate and display the hello world message
#### we can do so because of API
#### As a result when the URL is mentioned in the browser
#### the function is executed to give the result. 
#### URL root '/' rule is bound to the display_method() function.

# %% [markdown]
# ### Q4. Create a “/welcome” route to display the welcome message “Welcome to ABC Corporation” and a “/” route to show the following details:
# ####    Company Name: ABC Corporation
# ####    Location: India
# ####    Contact Detail: 999-999-9999
# ####    Attach the screenshot of the output in Jupyter Notebook.

# %%
@app.route("/welcome")
def display_welcome():
    return "Welcome to ABC Corporation"
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.3:5000/ (Press CTRL+C to quit)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
app=Flask(__name__)
@app.route("/")
def display_info():
    return "<h3>Company Name: ABC Corporation<br>Location: India<br>Contact Detail: 999-999-9999</h3>"
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.3:5000/ (Press CTRL+C to quit)
# 192.168.1.3 - - [03/Apr/2023 06:08:31] "GET / HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Q5. What function is used in Flask for URL Building? Write a Python code to demonstrate the working of the url_for() function.

# %%
#### The url_for() function is used to build a URL to the specific function 
#### it is done dynamically. 
#### The first argument is the name of the specified function
#### and then we can pass any number of keyword argument 
#### related to the variiable part of the URL

#### code..

app = Flask(__name__)  
@app.route('/admin')  
def admin():  
    return 'admin'   
  
@app.route('/student')  
def student():  
    return 'student'  
  
@app.route('/user/<name>')  
def user(name):  
    if name == 'admin':  
        return redirect(url_for('admin'))  
    if name == 'student':  
        return redirect(url_for('student'))  
if __name__ =='__main__': 
    app.run("0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.6:5000/ (Press CTRL+C to quit)
# 192.168.1.6 - - [11/Apr/2023 21:25:24] "GET / HTTP/1.1" 404 -
# 192.168.1.6 - - [11/Apr/2023 21:25:36] "GET /user HTTP/1.1" 404 -
# 192.168.1.6 - - [11/Apr/2023 21:25:47] "GET /student HTTP/1.1" 200 -

# %%
app=Flask(__name__)

@app.route('/passes/<int:marks>')
def passed(marks):
    return "He has passed"

@app.route('/falis/<int:marks>')
def failed(marks):
    return "He has failed"

@app.route('/checker/<int:number>')
def checker(number):
    res=""
    if number>80:
        res="passes"
    else:
        res="fails"
    return redirect(url_for(res,marks=number))
    
if __name__=="__main__":
    app.run("0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.6:5000/ (Press CTRL+C to quit)
# 192.168.1.6 - - [11/Apr/2023 22:18:15] "GET / HTTP/1.1" 404 -
# 192.168.1.6 - - [11/Apr/2023 22:18:26] "GET /checker/15 HTTP/1.1" 302 -
# 192.168.1.6 - - [11/Apr/2023 22:18:26] "GET /falis/15 HTTP/1.1" 200 -

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)
