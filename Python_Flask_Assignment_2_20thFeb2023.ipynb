# %% [markdown]
# ### Q1. Explain GET and POST methods.

# %%
#### Get and Post methods are the HTTP request methods
#### It is used for sending data to the server. 
#### HTTP protocol enables the communication between the client and the server
#### where a browser can be the client, and an application 
#### which is running on a computer system that is server
#### In web api we use HTTP protocol for sending data
#### Actually GET is commonly used in HTTP
#### It is not secure beacuse we can retrive data from it
#### Actually when we bind the app through route we declare in which
#### method the data will be transfered
#### POST is also used to send sensative data such as password, email 
#### Actually in transaction based banking system where the data are very 
#### secure its suggested that use POST instead of GET
#### By POST method we can send data in a secure manner in web server

# %% [markdown]
# ### Q2. Why is request used in Flask?

# %%
#### In Flask we have our own webpage 
#### It is known as client side 
#### The data whigh is given through the url and then it is processewd
#### by the the Server.
#### We can put our data through Request, in Flask
#### Actually it is an object that contains all the data 
#### That Reqiest object holds all data from the Client to Server. 
#### We can retrive the data by the GET/POST Methods
#### POST is used when your application expects the given data 
#### by the user is not visible by web page 
#### While if we use GET the it can be visible before submission
#### In that Request we use args 
#### It is actually parsed from the url
#### We do it using ? mark
#### By using get method we retrieve the that passed data to the server

# %% [markdown]
# #### Q3. Why is redirect() used in Flask?

# %%
#### Flask class has a redirect() function
#### When it is called, it returns a response object 
#### And it redirects the user to another target location 
#### It has some parameters
#### First one is location
####     location parameter is the URL where the resonse should be redirected
#### Secnd one is statuscode
####     it is sent through browswer's header, its default value is 302
####     it means found
####     yes, is has other values as response
#### Third one is response
####     actually it is responsible for instantiate that given response

# %% [markdown]
# ### Q4. What are templates in Flask? Why is the render_template() function used?

# %%
#### Templates are files that contain static data as well as placeholders
#### for dynamic data. 
#### A template is rendered with specific data
#### which produces a final document. 
#### Flask uses the Jinja template library to render templates. 
#### In your application, you will use templates to render HTML 
#### which will display in the user's browser.

#### Flask facilitates us to render the external HTML file 
#### We dont need to hardcode the HTML in the messaage function. 
#### Here, we can take advantage of the jinja2 template engine 
#### on which the flask is based.
#### example...

#### file.html (saved that below html doc as file.html)
#### <html>  
#### <head>  
####      <title>Message</title>  
#### </head>  
#### <body>  
####    <h1>Hi This is Victor</h1>  
#### </body>  
#### </html> 

#### from flask import *  
#### app = Flask(__name__)  
#### @app.route('/')  
#### def file():  
####       return render_template('file.html')  
#### if __name__ == '__main__':  
####   app.run(host="0.0.0.0")

# %% [markdown]
# ### Q5. Create a simple API. Use Postman to test it. Attach the screenshot of the output in the Jupyter Notebook

# %%
from flask import Flask, jsonify,request
app=Flask(__name__)

@app.route('/postman_example',methods=['POST'])
def print_message():
    if (request.method=='POST'):
        data=request.json['name']
        printing="I am "+data
    return jsonify(printing)
if __name__=="__main__":
    app.run(host="0.0.0.0")
# Out:
#  * Serving Flask app "__main__" (lazy loading)
#  * Environment: production
#    WARNING: This is a development server. Do not use it in a production deployment.
#    Use a production WSGI server instead.
#  * Debug mode: off
#  * Running on all addresses.
#    WARNING: This is a development server. Do not use it in a production deployment.
#  * Running on http://192.168.1.6:5000/ (Press CTRL+C to quit)
# 192.168.1.6 - - [17/Apr/2023 11:59:14] "POST /postman_example HTTP/1.1" 200 -

# %% [markdown]
# ![image-2.png](attachment:image-2.png)
